# %% [markdown]
# ### Load dependencies

# %%
import os
import shutil
import time
import pickle
import pandas as pd
import matplotlib.pyplot as pyplot
import librosa
import librosa.display
import gc
import numpy as np
import urllib

def download_rec(uri, rec_dir, filename):
    ### Downloads the uri to the rec_dir/filename
    if not os.path.exists(rec_dir+'/'+uri.replace('/','_')):
        try:
            urllib.request.urlretrieve (uri, rec_dir+'/'+filename)
        except Exception as e:
            print(e)
            print('Error downloading '+uri)
        return

# %% [markdown]
# ### Specify data paths:
#
# 1. train_set_dir - Folder where training data will be stored
# 2. recording_dir - Folder where audio recordings will be stored
# 3. sound_annotation_file - File storing template matching validation metadata
# 4. (Optional) sampling_rate - rate to resample training data recordings to

# %%
data_dir = '/home/jupyter/arbimon2-cnn/data/' #Added by andrew
train_set_dir = '/home/jupyter/arbimon2-cnn/data/train_tp/' # Folder where training data will be stored - true positives
train_dir_fp = '/home/jupyter/arbimon2-cnn/data/train_fp/' # directory with examples of false-positive spectrograms of each class
recording_dir = '/home/jupyter/arbimon2-cnn/data/recordings/' # Folder holding recordings
# sound_annotation_files = ['./example_annotations.csv'] # pattern matching results from Arbimon
sound_annotation_files = ['./Demo_MCC.csv'] # pattern matching results from Arbimon
# File storing ROIs of detected sounds (animal calls) 
#     Required columns:
#          species
#          x1 (start time of sound)
#          x2 (end time of sound)
#          url (recording file path)

sampling_rate = 48000 # training data recording sample rate

# %% [markdown]
# ### Run remaining cells to generate training data

# %%
if not os.path.exists(data_dir):
    os.mkdir(data_dir)
if not os.path.exists(recording_dir):
    os.mkdir(recording_dir)
if not os.path.exists(train_set_dir):
    os.mkdir(train_set_dir)
if not os.path.exists(train_dir_fp):
    os.mkdir(train_dir_fp)

# %%
if len(sound_annotation_files)==1:
    all_rois= pd.read_csv(sound_annotation_files[0])
    is_validated = all_rois['validated']!='(not validated)'
    all_rois = all_rois[is_validated] # only the validated recordings
elif len(sound_annotation_files)==0:
    print('Must provide an annotation file')
elif len(sound_annotation_files)>1:
    all_rois = pd.read_csv(sound_annotation_files[0])
    for i in sound_annotation_files[1:]:
        tmp = pd.read_csv(sound_annotation_files[i])
        all_rois = pd.concat([all_rois,tmp])
all_rois.head()
# Out:
#           id      recording           site  year  month  day  hour  minute  \
# 9   96849321  5ADE0894.flac          BCI03  2018      4   23    16      23
# 10  96849322  5ADE0894.flac          BCI03  2018      4   23    16      23
# 15  96849327  5AE95269.flac  BCI04_2_dorms  2018      5    2     5      53
# 19  96849331  5AD4E121.flac          BCI17  2018      4   16    17      45
# 22  96849334  5AD82F28.flac          BCI02  2018      4   19     5      54
#
#             species     songtype         x1         x2       y1       y2  \
# 9   Contopus virens  Common Song   9.253333  10.346667  2718.75  4781.25
# 10  Contopus virens  Common Song  51.381333  52.474667  2718.75  4781.25
# 15  Contopus virens  Common Song  40.746667  41.840000  2718.75  4781.25
# 19  Contopus virens  Common Song  31.578667  32.672000  2718.75  4781.25
# 22  Contopus virens  Common Song  11.328000  12.421333  2718.75  4781.25
#
#     frequency    validated                                                url  \
# 9       24000      present  https://arbimon.rfcx.org/api/project/bci-panam...
# 10      24000      present  https://arbimon.rfcx.org/api/project/bci-panam...
# 15      24000  not present  https://arbimon.rfcx.org/api/project/bci-panam...
# 19      24000  not present  https://arbimon.rfcx.org/api/project/bci-panam...
# 22      24000  not present  https://arbimon.rfcx.org/api/project/bci-panam...
#
#        score  site_id
# 9   0.559809     3094
# 10  0.559508     3094
# 15  0.248756     3191
# 19  0.200485     3146
# 22  0.204940     3127

# %%
print('Number of ROIs for each species\n')
for i in list(set(all_rois.species)):
    print(str(i)+'\t\t'+str(len(all_rois[all_rois.species==i])))
# Out:
# Number of ROIs for each species
#
# Contopus virens		133

# %%
# Save the audio recording and the spectrogram to the folders created above
window_length = 2 # sample time-window length in seconds
t0 = time.time()
for url in list(set(all_rois.url)): # get the unique urls
    print(url)
    rec_loaded = False
    # get all of the ROIs for the current url
    rois = all_rois[all_rois.url==url] 
    # loop over spectrogram ROIs
    for c in range(len(rois)): 
        try:
            print(rois.iloc[c].species + ' ' + rois.iloc[c].validated + ' ' + str(rois.iloc[c].score))
            # get the start and end times of the ROIs
            sound_start, sound_end = [rois.iloc[c].x1, rois.iloc[c].x2]
            # get the species name
            species = rois.iloc[c].species.replace(' ','_')
            # get the audio filename
            audio_filename = rois.iloc[0].recording
            # create the species name folder if it doesnt already exist
            if not os.path.exists(train_set_dir + '/' + str(species)):
                os.mkdir(train_set_dir + '/' + str(species))
            if not os.path.exists(train_dir_fp + '/' + str(species)):
                os.mkdir(train_dir_fp + '/' + str(species))
            if rois.iloc[c]['validated']=='present':
                folder = train_set_dir
            else:
                folder = train_dir_fp
            # get the shift in time to be able to standardise all samples to 2 seconds long, e.g. if the sound is 1.4s long the shift will be 0.3s and so there will be 0.3s before and 0.3s after to make the sample 2s long
            shft = ((sound_end - sound_start) - window_length)/2
            start_sample = round(sampling_rate * (sound_start + shft)) # e.g. 24s in will be (48000*24) = 1152000
            # ensure the start time is not <0
            start_sample = max(start_sample, 0)
            # append the start and end times of the sample into the filename of the spectrogram
            # e.g. project_1_site_506_2014_4_sabana_seca1-2014-04-04_03-20_22.3-24.3
            #                      is from 04/04/2014 at 03:20 and between 22.3s to 24.3s
            # get the folder where the spectrogram will be created
            filename = rois.iloc[0].recording.split('.')[0] + '_' + str(round(start_sample/sampling_rate,2)) + '-' + str(round((start_sample/sampling_rate) + window_length,2)) + '.png'
            # if the spectrogram has not been created - create it and write it to the train_set_dir folder
            print(folder + str(species) + '/' + filename)
            if not os.path.exists(folder + str(species) + '/' + filename):
                if not rec_loaded: # has the recording been downloaded
                    if not os.path.exists(recording_dir + '/' + audio_filename): 
                        # download the recording
                        download_rec(url, recording_dir, audio_filename)
                    try:
                        # load the audio file
                        audio_data, sampling_rate = librosa.load(recording_dir+audio_filename, sr=sampling_rate)
                        rec_loaded = True
                    except Exception as e:
                        print(e)
                        continue
                # create the spectrogram
                S = librosa.feature.melspectrogram(y = audio_data[int(start_sample): int(start_sample+round(sampling_rate*window_length))], 
                                               sr = sampling_rate,
                                               n_fft=2048, 
                                               hop_length=512, 
                                               win_length=1024)
                dpi=100
                fig = pyplot.figure(num=None, figsize=(300/dpi, 300/dpi), dpi=dpi)
                pyplot.subplot(222)
                ax = pyplot.axes()
                ax.set_axis_off()
                librosa.display.specshow(librosa.power_to_db(S, ref=np.max))
                # save the spectrogram to file
                pyplot.savefig(folder+str(species.replace(' ','_'))+'/'+filename, bbox_inches='tight', transparent=True, pad_inches=0.0)
                pyplot.close()
                
        except Exception as e:
            print(e)
            continue
        
    rec_loaded = False
# Out:
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3355783
# Contopus virens present 0.4759610536910118
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADDFD18_36.83-38.83.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3473710
# Contopus virens not present 0.2487563816946783
# /home/jupyter/arbimon2-cnn/data/train_fp/Contopus_virens/5AE95269_40.29-42.29.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3612467
# Contopus virens not present 0.3080719745762741
# /home/jupyter/arbimon2-cnn/data/train_fp/Contopus_virens/5AE4131B_32.77-34.77.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3380982
# Contopus virens present 0.5425935560452593
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADF16D6_18.76-20.76.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3413919
# Contopus virens present 0.592735169472384
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AE043F3_23.06-25.06.png
# Contopus virens present 0.5919882370884905
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AE043F3_33.63-35.63.png
# Contopus virens present 0.5908488512731054
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AE043F3_48.77-50.77.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3482374
# Contopus virens present 0.5655332439962846
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AE2ED10_48.47-50.47.png
# Contopus virens present 0.5644716183953069
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AE2ED10_33.61-35.61.png
# Contopus virens present 0.5494406326057671
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AE2ED10_46.11-48.11.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3418544
# Contopus virens present 0.6061865692397856
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADCCE03_53.22-55.22.png
# Contopus virens present 0.596460886156249
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADCCE03_45.63-47.63.png
# Contopus virens present 0.5900430553442425
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADCCE03_22.53-24.53.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3427633
# Contopus virens present 0.5900638464408992
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADC87A6_17.5-19.5.png
# Contopus virens present 0.5654076488811612
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADC87A6_37.73-39.73.png
# Contopus virens present 0.5547307876722776
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADC87A6_33.78-35.78.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3358585
# Contopus virens present 0.3472265514317287
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD87228_56.99-58.99.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3311776
# Contopus virens not present 0.2627132296861838
# /home/jupyter/arbimon2-cnn/data/train_fp/Contopus_virens/5AD44824_47.21-49.21.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3428218
# Contopus virens not present 0.232324433085939
# /home/jupyter/arbimon2-cnn/data/train_fp/Contopus_virens/5AD44337_53.17-55.17.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3311926
# Contopus virens present 0.5472337713050603
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD71331_12.84-14.84.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3639951
# Contopus virens present 0.5517800837086617
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AE44458_9.21-11.21.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3368084
# Contopus virens not present 0.4410362798277281
# /home/jupyter/arbimon2-cnn/data/train_fp/Contopus_virens/5AD8A4E2_40.83-42.83.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3641820
# Contopus virens present 0.5613340412361677
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADE1FE0_26.13-28.13.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3416092
# Contopus virens present 0.6018313962136198
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADF0076_1.31-3.31.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3368433
# Contopus virens present 0.6023846218661955
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD75BEA_33.7-35.7.png
# Contopus virens present 0.5908738279824949
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD75BEA_41.77-43.77.png
# Contopus virens present 0.5683601918077351
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD75BEA_13.86-15.86.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3365422
# Contopus virens present 0.5900749951887657
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADA1206_4.74-6.74.png
# Contopus virens present 0.5664774404387071
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADA1206_8.15-10.15.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3393896
# Contopus virens present 0.5954206475659863
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD709DF_44.22-46.22.png
# Contopus virens present 0.5953707954446402
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD709DF_53.58-55.58.png
# Contopus virens present 0.5688086114507054
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD709DF_28.12-30.12.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3484490
# Contopus virens present 0.5817620247832269
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD84DEF_40.33-42.33.png
# Contopus virens present 0.5649717854180193
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD84DEF_28.44-30.44.png
# Contopus virens present 0.5561350857193893
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD84DEF_16.34-18.34.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3357922
# Contopus virens present 0.4325288615292824
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADADA90_16.85-18.85.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3308592
# Contopus virens not present 0.4073940754202765
# /home/jupyter/arbimon2-cnn/data/train_fp/Contopus_virens/5ADECABF_41.77-43.77.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3423976
# Contopus virens present 0.5492584058104266
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD5A77E_40.42-42.42.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3380673
# Contopus virens present 0.5699737190758621
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADF70E7_30.0-32.0.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3362523
# Contopus virens not present 0.2780347737574641
# /home/jupyter/arbimon2-cnn/data/train_fp/Contopus_virens/5AD440B8_56.18-58.18.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3310172
# Contopus virens not present 0.3742186582250854
# /home/jupyter/arbimon2-cnn/data/train_fp/Contopus_virens/5AD6E1BF_26.08-28.08.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3309963
# Contopus virens not present 0.3269186628524157
# /home/jupyter/arbimon2-cnn/data/train_fp/Contopus_virens/5ADED67C_40.5-42.5.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3484499
# Contopus virens present 0.9905943285937944
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD8493F_7.13-9.13.png
# Contopus virens present 0.6393620872972262
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD8493F_11.11-13.11.png
# Contopus virens present 0.6103653171371499
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD8493F_3.13-5.13.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3635494
# Contopus virens present 0.5593666283310318
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD846CE_18.28-20.28.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3358627
# Contopus virens present 0.3901301562760088
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD99368_47.05-49.05.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3394941
# Contopus virens not present 0.200485114763845
# /home/jupyter/arbimon2-cnn/data/train_fp/Contopus_virens/5AD4E121_31.13-33.13.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3631079
# Contopus virens present 0.6037112095100872
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD9B120_46.22-48.22.png
# Contopus virens present 0.588923338325282
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD9B120_52.99-54.99.png
# Contopus virens present 0.581327317539139
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD9B120_55.67-57.67.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3416443
# Contopus virens present 0.5822052362438039
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADC5B17_54.07-56.07.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3630291
# Contopus virens present 0.6712866979457143
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADB0E58_52.44-54.44.png
# Contopus virens present 0.5625387859528859
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADB0E58_33.67-35.67.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3365344
# Contopus virens present 0.4946362754053217
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADEDF78_50.16-52.16.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3419510
# Contopus virens present 0.6103241771296009
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADDC8BE_32.8-34.8.png
# Contopus virens present 0.5983702729251655
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADDC8BE_45.42-47.42.png
# Contopus virens present 0.5965769426198344
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADDC8BE_51.69-53.69.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3360702
# Contopus virens not present 0.2112299979844878
# /home/jupyter/arbimon2-cnn/data/train_fp/Contopus_virens/5AD58B30_35.99-37.99.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3643912
# Contopus virens present 0.5809075884363794
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADA2B60_28.43-30.43.png
# Contopus virens present 0.555673031983555
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADA2B60_18.71-20.71.png
# Contopus virens present 0.5552505485285485
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADA2B60_11.05-13.05.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3628982
# Contopus virens present 0.59334416353068
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADCB438_21.7-23.7.png
# Contopus virens present 0.5788798646731288
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADCB438_25.0-27.0.png
# Contopus virens present 0.5660349358612607
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADCB438_32.14-34.14.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3364707
# Contopus virens present 0.4503323452516155
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADDC638_34.68-36.68.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3628307
# Contopus virens present 0.565467630758939
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADDA5A0_24.52-26.52.png
# Contopus virens present 0.5467731866744928
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADDA5A0_30.34-32.34.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3309799
# Contopus virens not present 0.262242605895678
# /home/jupyter/arbimon2-cnn/data/train_fp/Contopus_virens/5ADC23EB_28.72-30.72.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3422185
# Contopus virens present 0.6217911430372669
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD77B60_33.31-35.31.png
# Contopus virens present 0.6083372371187197
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD77B60_16.99-18.99.png
# Contopus virens present 0.6071548364793793
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD77B60_28.13-30.13.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3306641
# Contopus virens present 0.5620883378455768
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD705AD_19.61-21.61.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3627219
# Contopus virens present 0.5770703818754509
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADF1EF8_25.04-27.04.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3306627
# Contopus virens present 0.5526776428369271
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADC41A6_54.3-56.3.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3628063
# Contopus virens present 0.6054298220579224
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADC63B9_46.28-48.28.png
# Contopus virens present 0.5907362803114956
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADC63B9_54.61-56.61.png
# Contopus virens present 0.563435399415697
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADC63B9_50.98-52.98.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3386130
# Contopus virens present 0.6072699303094409
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD77077_49.12-51.12.png
# Contopus virens present 0.5858810558305294
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD77077_36.66-38.66.png
# Contopus virens present 0.5838413914895748
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD77077_42.74-44.74.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3307661
# Contopus virens present 0.5714337462313259
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADB038D_19.1-21.1.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3444967
# Contopus virens present 0.607058716788343
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADADFB3_30.93-32.93.png
# Contopus virens present 0.5900174403947174
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADADFB3_37.43-39.43.png
# Contopus virens present 0.5876521121975548
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADADFB3_44.92-46.92.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3443827
# Contopus virens present 0.5902741729853429
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADC383B_19.76-21.76.png
# Contopus virens present 0.5784817849826926
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADC383B_38.14-40.14.png
# Contopus virens present 0.5715540197295085
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADC383B_25.7-27.7.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3486612
# Contopus virens present 0.5566385074080222
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AE04C33_22.28-24.28.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3402040
# Contopus virens not present 0.3031578531683364
# /home/jupyter/arbimon2-cnn/data/train_fp/Contopus_virens/5ADECB69_14.26-16.26.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3312368
# Contopus virens not present 0.2154496565353704
# /home/jupyter/arbimon2-cnn/data/train_fp/Contopus_virens/5ADAF52B_48.37-50.37.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3298709
# Contopus virens present 0.5644404106152472
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADB264C_33.66-35.66.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3309235
# Contopus virens not present 0.2835244976217635
# /home/jupyter/arbimon2-cnn/data/train_fp/Contopus_virens/5AD5903F_15.69-17.69.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3391069
# Contopus virens not present 0.2549085980952526
# /home/jupyter/arbimon2-cnn/data/train_fp/Contopus_virens/5AE01839_47.76-49.76.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3316387
# Contopus virens present 0.6134150079199521
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADF187B_16.27-18.27.png
# Contopus virens present 0.5917747271086489
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADF187B_41.68-43.68.png
# Contopus virens present 0.587679573214375
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADF187B_22.52-24.52.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3311226
# Contopus virens present 0.5523980628981147
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD46505_0.65-2.65.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3362941
# Contopus virens present 0.5191914445902781
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD9BA48_5.78-7.78.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3357838
# Contopus virens not present 0.2049402592525016
# /home/jupyter/arbimon2-cnn/data/train_fp/Contopus_virens/5AD82F28_10.87-12.87.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3324383
# Contopus virens present 0.6152089389187303
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD70EC5_47.0-49.0.png
# Contopus virens present 0.61360574084203
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD70EC5_53.91-55.91.png
# Contopus virens present 0.610532596488576
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD70EC5_24.14-26.14.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3385490
# Contopus virens present 0.5932362395000075
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADCD297_39.22-41.22.png
# Contopus virens present 0.5811481458849376
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADCD297_28.67-30.67.png
# Contopus virens present 0.5759822893507628
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADCD297_56.95-58.95.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3392240
# Contopus virens not present 0.2588241603285797
# /home/jupyter/arbimon2-cnn/data/train_fp/Contopus_virens/5ADC2D19_43.55-45.55.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3483864
# Contopus virens present 0.5491143807626205
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD9B487_27.47-29.47.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3306381
# Contopus virens present 0.5755822744844412
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD85985_32.31-34.31.png
# Contopus virens present 0.568398162449812
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD85985_36.26-38.26.png
# Contopus virens present 0.5524076267903565
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD85985_41.74-43.74.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3628303
# Contopus virens present 0.5521017235837827
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADDAE18_50.91-52.91.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3303529
# Contopus virens not present 0.2267934558670018
# /home/jupyter/arbimon2-cnn/data/train_fp/Contopus_virens/5AD6DF6C_30.49-32.49.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3304233
# Contopus virens not present 0.2416377685140059
# /home/jupyter/arbimon2-cnn/data/train_fp/Contopus_virens/5AD43CDB_17.08-19.08.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3313673
# Contopus virens present 0.5564265447168593
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD453D5_22.58-24.58.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3307178
# Contopus virens not present 0.2144590413193535
# /home/jupyter/arbimon2-cnn/data/train_fp/Contopus_virens/5ADCAB73_44.24-46.24.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3369512
# Contopus virens present 0.57861712714594
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADB36A2_11.1-13.1.png
# Contopus virens present 0.5771026636598559
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADB36A2_14.99-16.99.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3356472
# Contopus virens present 0.3891282458526501
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADEDE18_23.94-25.94.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3364400
# Contopus virens present 0.513587283275101
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADC30C0_35.83-37.83.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3361854
# Contopus virens present 0.4415513583371985
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD5EE98_1.57-3.57.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3428319
# Contopus virens present 0.5645888244750092
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD8A39B_6.63-8.63.png
# Contopus virens present 0.5502002374945824
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD8A39B_10.65-12.65.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3422351
# Contopus virens present 0.5996324558663193
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD9E70B_42.57-44.57.png
# Contopus virens present 0.5910206507244716
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD9E70B_55.07-57.07.png
# Contopus virens present 0.5712837000995051
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AD9E70B_46.63-48.63.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3360064
# Contopus virens present 0.4637488195933306
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADCB9A8_41.48-43.48.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3298381
# Contopus virens present 0.5598093293293003
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADE0894_8.8-10.8.png
# Contopus virens present 0.5595081659635696
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADE0894_50.93-52.93.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3481812
# Contopus virens present 0.5575996000132576
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5AE19DE2_6.16-8.16.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3428400
# Contopus virens present 0.5507397831416478
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADB130B_12.63-14.63.png
# Contopus virens present 0.5502490994711907
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADB130B_24.43-26.43.png
# https://arbimon.rfcx.org/api/project/bci-panama-2018/recordings/download/3642460
# Contopus virens present 0.5467357349510134
# /home/jupyter/arbimon2-cnn/data/train_tp/Contopus_virens/5ADF1D26_14.98-16.98.png
